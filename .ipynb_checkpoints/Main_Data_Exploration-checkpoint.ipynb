# %% [markdown]
# # Exploración y Limpieza de Datos
# ## Selección inicial de características

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#Read main data to DataFrame
df = pd.read_stata('Cash_and_Childhood_Development_Replication/macoursetal_main.dta')

# %%
#Read Variable Descriptions to DataFrame

Feat_df = pd.read_excel('VarNames_Labels.xlsm', header = 1)
pd.set_option('display.max_rows', None)

Feat_df[['Variable_Name', 'Variable_Label']]
# Out:
#                   Variable_Name  \
# 0                     hogarid08
# 1                            cp
# 2                   hogarid_old
# 3                        cp_old
# 4                 age_months_08
# 5                     hogarid06
# 6                           i06
# 7            s4p7_parasite_i_08
# 8            s4p39_daysbed_i_08
# 9               cons_food_pc_08
# 10               cons_tot_pc_08
# 11                         cp06
# 12                    unique_05
# 13                s1age_head_05
# 14                  s1hhsize_05
# 15              s1hhsz_undr5_05
# 16               s1hhsz_5_14_05
# 17              s1hhsz_15_24_05
# 18              s1hhsz_25_64_05
# 19             s1hhsz_65plus_05
# 20               s1male_head_05
# 21             s2mother_inhs_05
# 22             s3ap5_rooms_h_05
# 23            s3ap23_stime_h_05
# 24            s3ap24_htime_h_05
# 25           s3ap25_hqtime_h_05
# 26              s3atoilet_hh_05
# 27        s3awater_access_hh_05
# 28            s3aelectric_hh_05
# 29           s4p6_vitamina_i_05
# 30           s4p7_parasite_i_05
# 31             s11ownland_hh_05
# 32              cons_food_pc_05
# 33               cons_tot_pc_05
# 34                      tvip_05
# 35                    height_05
# 36                    a10whz_05
# 37                    weight_05
# 38                        itt_i
# 39                    itt_all_i
# 40                    yrsedfath
# 41               a3leerdummy_08
# 42                 age_transfer
# 43                      bweight
# 44                  noform_i_08
# 45                 e1bp3_toy_08
# 46                     cpmom_08
# 47                age_months_06
# 48                    s1male_06
# 49           s4p7_parasite_i_06
# 50               cons_tot_pc_06
# 51                a5sscore_i_06
# 52              a6smemory_p1_06
# 53              a6smemory_p2_06
# 54                 a7a_delay_06
# 55               a7a_caution_06
# 56                 a7b_delay_06
# 57               a7b_caution_06
# 58                 a7c_delay_06
# 59               a7c_caution_06
# 60                 a7d_delay_06
# 61               a7d_caution_06
# 62             a9sgrossmotor_06
# 63                    height_06
# 64                    weight_06
# 65               a3leerdummy_06
# 66                     cpmom_06
# 67                            T
# 68                         male
# 69                       TREAT1
# 70                       TREAT2
# 71                       TREAT3
# 72                       TREAT4
# 73                       ed_mom
# 74                         MUN1
# 75                         MUN2
# 76                         MUN3
# 77                         MUN4
# 78                         MUN5
# 79                         MUN6
# 80                   com_haz_05
# 81                   com_waz_05
# 82                  com_tvip_05
# 83               com_control_05
# 84                   com_vit_05
# 85                com_deworm_05
# 86                   com_notvip
# 87                mominhouse_06
# 88               guardianmom_06
# 89                    titmom_06
# 90                mominhouse_08
# 91               guardianmom_08
# 92                    titmom_08
# 93                     sample08
# 94                     sample06
# 95                   a13cesd_08
# 96                    e5home_08
# 97                 a3stories_08
# 98                nrhourread_08
# 99                hourscuida_08
# 100           hourstrabcuida_08
# 101              hourstotalc_08
# 102                 weighted_08
# 103                  a3lapiz_08
# 104                 propfood_08
# 105                 prstap_f_08
# 106           pranimalprot_f_08
# 107             prfruitveg_f_08
# 108                vitamiron_08
# 109                    s4p39_06
# 110                 propfood_06
# 111                 prstap_f_06
# 112           pranimalprot_f_06
# 113             prfruitveg_f_06
# 114                 weighted_06
# 115                  a3toy6M_06
# 116                  a3lapiz_06
# 117                a3stories_06
# 118               nrhourread_06
# 119                vitamiron_06
# 120                  a13cesd_06
# 121                  a14home_06
# 122                   z_tvip_06
# 123                   z_tvip_08
# 124                 z_social_06
# 125                 z_social_08
# 126               z_language_06
# 127               z_language_08
# 128               z_finmotor_06
# 129               z_finmotor_08
# 130                 z_memory_06
# 131                 z_memory_08
# 132                z_grmotor_06
# 133                z_grmotor_08
# 134               z_legmotor_06
# 135               z_legmotor_08
# 136               z_behavior_06
# 137               z_behavior_08
# 138                 z_height_06
# 139                 z_height_08
# 140                 z_weight_06
# 141                 z_weight_08
# 142               z_martians_08
# 143                    z_all_06
# 144                    z_all_08
# 145                  z_tvip_06m
# 146                  z_tvip_08m
# 147                z_social_06m
# 148                z_social_08m
# 149              z_language_06m
# 150              z_language_08m
# 151              z_finmotor_06m
# 152              z_finmotor_08m
# 153                z_memory_06m
# 154                z_memory_08m
# 155               z_grmotor_06m
# 156               z_grmotor_08m
# 157              z_legmotor_06m
# 158              z_legmotor_08m
# 159              z_behavior_06m
# 160              z_behavior_08m
# 161                z_height_06m
# 162                z_height_08m
# 163                z_weight_06m
# 164                z_weight_08m
# 165              z_martians_08m
# 166                bweight_miss
# 167               bweight_inter
# 168                tvip_05_miss
# 169               tvip_05_inter
# 170              height_05_miss
# 171             height_05_inter
# 172              weight_05_miss
# 173             weight_05_inter
# 174                 ed_mom_miss
# 175                ed_mom_inter
# 176                 weighted_05
# 177                 propfood_05
# 178                 prstap_f_05
# 179           pranimalprot_f_05
# 180             prfruitveg_f_05
# 181                martians_pct
# 182       s6p14_indays_i_08_mom
# 183      s6wrkdys_agwa_i_08_mom
# 184   s6wrkdys_nonagwa_i_08_mom
# 185  s6wrkdys_nonagslf_i_08_mom
# 186      s6wrkdys_prof_i_08_mom
# 187         s6totwrkdays_08_mom
# 188               a13cesd_08mom
# 189                e5home_08mom
# 190       s6p14_indays_i_06_mom
# 191      s6wrkdys_agwa_i_06_mom
# 192   s6wrkdys_nonagwa_i_06_mom
# 193  s6wrkdys_nonagslf_i_06_mom
# 194      s6wrkdys_prof_i_06_mom
# 195         s6totwrkdays_06_mom
# 196               a13cesd_06mom
# 197               a14home_06mom
#
#                                         Variable_Label
# 0                               Full 2008 household ID
# 1                                     Person code 2008
# 2                                 household ID in 2005
# 3                                     Person code 2005
# 4                                Age in months in 2008
# 5                    Household ID in 2006 (first part)
# 6                      Household ID in 2006 (2nd part)
# 7              Got deworming medicine in last 6 months
# 8    number of days in bed for illness in last 30 days
# 9                    Per capita food expenditures 2008
# 10                  Per capita total expenditures 2008
# 11                                    Person code 2006
# 12                                         communityid
# 13     age for the household head at time of interview
# 14                                      household size
# 15                          # people under 5 yrs in hh
# 16                     # people between 5 and 15 in hh
# 17                    # people between 15 and 25 in hh
# 18                    # people between 25 and 65 in hh
# 19                      # people 65 yrs and over in hh
# 20                                   gender of hh head
# 21        mother of this person lives in the household
# 22                                     number of rooms
# 23                           time to prim. school, hrs
# 24                          time to health center, hrs
# 25                           time to municipal hq, hrs
# 26           household has a toilet for waste disposal
# 27               Access to piped water within property
# 28                               Access to electricity
# 29                    vitamin A in last 6 mos,under 5y
# 30            anti-parasite in the last 6 mos,under 5y
# 31                                        hh owns land
# 32                    annual pc total food consumption
# 33                            pc consumption aggregate
# 34                                      TVIP Raw score
# 35                              Height-for-age z-score
# 36                           weight for height z-score
# 37                              Weight-for-age z-score
# 38                                     Intent to treat
# 39                             Intent to treat - 4 cat
# 40                        Years of education of father
# 41                       somebody reads to child in 08
# 42             Age in months at time of first transfer
# 43                                        Birth weight
# 44                                Numero de formulario
# 45                                    Has toy in house
# 46                             Person code mother 2008
# 47                                       age in months
# 48                                    gender of person
# 49             Got deworming medicine in last 6 months
# 50                            pc consumption aggregate
# 51                             TVIP standardized score
# 52          standardize score McCarthy memory 1st part
# 53          standardize score McCarthy memory 2nd part
# 54             personal-social skills: delayed for age
# 55   personal-social skills: at least one in lowest...
# 56                    language skills: delayed for age
# 57   language skills: at least one in lowest quarti...
# 58                  fine motor skills: delayed for age
# 59   fine motor skills: at least one in lowest quar...
# 60                 gross motor skills: delayed for age
# 61   gross motor skills: at least one in lowest qua...
# 62              standardize score McCarthy gross motor
# 63                 height for age z-score (antrop age)
# 64                  weight for age z-score(antrop age)
# 65                       somebody reads to child in 06
# 66                             Person code mother 2006
# 67       =1 for treatment communities; = 0 for control
# 68                           =1 for boys, =0 for girls
# 69                                  itt_all_i==Control
# 70                              itt_all_i==Bono Basico
# 71                            itt_all_i==Bono+Training
# 72                               itt_all_i==Bono+Grant
# 73     Number of years of education mother at baseline
# 74                                   Municipal dummy 1
# 75                                   Municipal dummy 2
# 76                                   Municipal dummy 3
# 77                                   Municipal dummy 4
# 78                                   Municipal dummy 5
# 79                                   Municipal dummy 6
# 80           community average baseline height-for-age
# 81           community average baseline weight-for-age
# 82               Community average baseline tvip score
# 83          Community average baseline weight controls
# 84        Community average children received vitamins
# 85   Community average children received deworming ...
# 86   Share of children in community without tvip sc...
# 87          mother lives in same hh in 06 and is panel
# 88                       guardian 06 is same as mother
# 89   titular of 05 is same person as person reporte...
# 90          mother lives in same hh in 08 and is panel
# 91                       guardian 08 is same as mother
# 92   titular of 05 is same person as person reporte...
# 93      =1 for children with at least one test in 2008
# 94      =1 for children with at least one test in 2006
# 95   CES Depression scale (max depr = 60) for careg...
# 96   Composite HOME scale (max 11) higher score is ...
# 97               Somebody tells stories/sings to child
# 98              Number of hours read to child per week
# 99         Number of hours uniquely caregiving per day
# 100   Number of hours caregiving while working per day
# 101                   Total number of hours caregiving
# 102                                            Weighed
# 103                         Has pen and paper in house
# 104                       % food in total expenditures
# 105               % staples in total food expenditures
# 106       % animal proteins in total food expenditures
# 107  % fruit and vegetables in total food expenditures
# 108               Got vitamin or iron in last 6 months
# 109  number of days in bed for illness in last 30 days
# 110                       % food in total expenditures
# 111               % staples in total food expenditures
# 112       % animal proteins in total food expenditures
# 113  % fruit and vegetables in total food expenditures
# 114                           Weighed in last 6 months
# 115                                   Has toy in house
# 116                         Has pen and paper in house
# 117              Somebody tells stories/sings to child
# 118             Number of hours read to child per week
# 119               Got vitamin or iron in last 6 months
# 120  CES Depression scale (max depr = 60) for careg...
# 121  Composite HOME scale (max 11) higher score is ...
# 122                                  z-score tvip 2006
# 123                                  z-score tvip 2008
# 124          z-score denver social-personal score 2006
# 125          z-score denver social-personal score 2008
# 126                 z-score denver language score 2006
# 127                 z-score denver language score 2008
# 128               z-score denver fine motor score 2006
# 129               z-score denver fine motor score 2008
# 130              z-score memory for numbers score 2006
# 131              z-score memory for numbers score 2008
# 132              z-score denver gross motor score 2006
# 133              z-score denver gross motor score 2008
# 134                       z-score leg motor score 2006
# 135                       z-score leg motor score 2008
# 136              z-score behavioral problem index 2006
# 137              z-score behavioral problem index 2008
# 138                        z-score height-for-age 2006
# 139                        z-score height-for-age 2008
# 140                        z-score weight-for-age 2006
# 141                        z-score weight-for-age 2008
# 142                    z-score associative memory 2008
# 143                   z-score of sum of all tests 2006
# 144                   z-score of sum of all tests 2008
# 145  z-score tvip 2006 for sample with tvip in 2006...
# 146  z-score tvip 2008 for sample with tvip in 2006...
# 147  z-score denver social-personal score 2006 for ...
# 148  z-score denver social-personal score 2008 for ...
# 149  z-score denver language score 2006 for sample ...
# 150  z-score denver language score 2008 for sample ...
# 151  z-score denver fine motor score 2006 for sampl...
# 152  z-score denver fine motor score 2008 for sampl...
# 153  z-score memory for numbers score 2006 for samp...
# 154  z-score memory for numbers score 2008 for samp...
# 155  z-score denver gross motor score 2006 for samp...
# 156  z-score denver gross motor score 2008 for samp...
# 157  z-score leg motor score 2006 for sample with l...
# 158  z-score leg motor score 2008 for sample with l...
# 159  z-score behavioral problem index 2006 for samp...
# 160  z-score behavioral problem index 2008 for samp...
# 161  z-score height-for-age 2006 for sample with he...
# 162  z-score height-for-age 2008 for sample with he...
# 163  z-score weight-for-age 2006  for sample with w...
# 164  z-score weight-for-age 2008  for sample with w...
# 165                    z-score associative memory 2008
# 166      dummy = 1 if baseline birth weight is missing
# 167  Baseline birth weight interacted with bweight_...
# 168              dummy = 1 if baseline TVIP is missing
# 169            Baseline tvip interacted with tvip_miss
# 170            dummy = 1 if baseline height is missing
# 171        Baseline height interacted with height_miss
# 172            dummy = 1 if baseline weight is missing
# 173        Baseline weight interacted with weight_miss
# 174  dummy = 1 if baseline education mother is missing
# 175  Baseline education mother interacted with ed_m...
# 176                           Weighed in last 6 months
# 177                       % food in total expenditures
# 178               % staples in total food expenditures
# 179       % animal proteins in total food expenditures
# 180  % fruit and vegetables in total food expenditures
# 181  Associative memory percentile compared to inte...
# 182                    Number of days absent from home
# 183  total # days worked in 12 mo for ag wage, 6 an...
# 184  total # days worked in 12 mo for non-ag wage, ...
# 185  total # days worked in 12 mo for non-ag self, ...
# 186  total # days worked in 12 mo for profes wage, ...
# 187                Total number of days worked in 2008
# 188  CES Depression scale (max depr = 60) for mothe...
# 189  Composite HOME scale (max 11) higher score is ...
# 190                    Number of days absent from home
# 191  total # days worked in 12 mo for ag wage, 6 an...
# 192  total # days worked in 12 mo for non-ag wage, ...
# 193  total # days worked in 12 mo for non-ag self, ...
# 194  total # days worked in 12 mo for profes wage, ...
# 195                Total number of days worked in 2006
# 196  CES Depression scale (max depr = 60) for mothe...
# 197  Composite HOME scale (max 11) higher score is ...

# %% [markdown]
# Después de analizar las variables disponibles y estudiar la organización del estudio, se realiza una selección inicial de variables basada en el conocimiento previo sobre sus potenciales efectos sobre las variables resultado (es decir, se seleccionan las variables que se consideran más implicadas en el desarrollo cognitivo de los niños).
#
# Una vez seleccionadas, se clasifican también según el tipo de variable para facilitar la posterior exploración, siguiendo:
#
# 1. BIN:  variable categórica binaria, indistintamente codificada como una *dummy variable* o en forma de texto
# 1. CAT: variable categórica, generalmente en forma de texto
# 1. CONT: variable numérica continua
# 1. FREQ: variable numérica continua que expresa frecuencia (valores entre 0 y 1)
# 1. ID: variable generalmente numérica que codifica un identificador, por lo que se considera categórica
# 1. ORD: variable numérica discreta

# %%
Feat_df.drop(Feat_df[Feat_df.Prior_Knowledge == "-"].index,  inplace=True)
Feat_df.drop(Feat_df[Feat_df.Prior_Knowledge == "X"].index,  inplace=True)

Feat_df.drop(columns=['VarIndex', 'Base_Model', 'NaN_Management'], inplace=True)

Feat_df[['Variable_Name', 'Variable_Label', 'Type']]
# Out:
#              Variable_Name                                     Variable_Label  \
# 2              hogarid_old                               household ID in 2005
# 3                   cp_old                                   Person code 2005
# 12               unique_05                                        communityid
# 13           s1age_head_05    age for the household head at time of interview
# 14             s1hhsize_05                                     household size
# 15         s1hhsz_undr5_05                         # people under 5 yrs in hh
# 16          s1hhsz_5_14_05                    # people between 5 and 15 in hh
# 17         s1hhsz_15_24_05                   # people between 15 and 25 in hh
# 18         s1hhsz_25_64_05                   # people between 25 and 65 in hh
# 19        s1hhsz_65plus_05                     # people 65 yrs and over in hh
# 20          s1male_head_05                                  gender of hh head
# 21        s2mother_inhs_05       mother of this person lives in the household
# 22        s3ap5_rooms_h_05                                    number of rooms
# 23       s3ap23_stime_h_05                          time to prim. school, hrs
# 24       s3ap24_htime_h_05                         time to health center, hrs
# 25      s3ap25_hqtime_h_05                          time to municipal hq, hrs
# 26         s3atoilet_hh_05          household has a toilet for waste disposal
# 27   s3awater_access_hh_05              Access to piped water within property
# 28       s3aelectric_hh_05                              Access to electricity
# 29      s4p6_vitamina_i_05                   vitamin A in last 6 mos,under 5y
# 30      s4p7_parasite_i_05           anti-parasite in the last 6 mos,under 5y
# 31        s11ownland_hh_05                                       hh owns land
# 32         cons_food_pc_05                   annual pc total food consumption
# 33          cons_tot_pc_05                           pc consumption aggregate
# 34                 tvip_05                                     TVIP Raw score
# 35               height_05                             Height-for-age z-score
# 36               a10whz_05                          weight for height z-score
# 37               weight_05                             Weight-for-age z-score
# 38                   itt_i                                    Intent to treat
# 39               itt_all_i                            Intent to treat - 4 cat
# 40               yrsedfath                       Years of education of father
# 42            age_transfer            Age in months at time of first transfer
# 43                 bweight                                       Birth weight
# 49      s4p7_parasite_i_06            Got deworming medicine in last 6 months
# 51           a5sscore_i_06                            TVIP standardized score
# 52         a6smemory_p1_06         standardize score McCarthy memory 1st part
# 53         a6smemory_p2_06         standardize score McCarthy memory 2nd part
# 54            a7a_delay_06            personal-social skills: delayed for age
# 56            a7b_delay_06                   language skills: delayed for age
# 58            a7c_delay_06                 fine motor skills: delayed for age
# 60            a7d_delay_06                gross motor skills: delayed for age
# 62        a9sgrossmotor_06             standardize score McCarthy gross motor
# 63               height_06                height for age z-score (antrop age)
# 64               weight_06                 weight for age z-score(antrop age)
# 66                cpmom_06                            Person code mother 2006
# 67                       T      =1 for treatment communities; = 0 for control
# 68                    male                          =1 for boys, =0 for girls
# 69                  TREAT1                                 itt_all_i==Control
# 70                  TREAT2                             itt_all_i==Bono Basico
# 71                  TREAT3                           itt_all_i==Bono+Training
# 72                  TREAT4                              itt_all_i==Bono+Grant
# 73                  ed_mom    Number of years of education mother at baseline
# 74                    MUN1                                  Municipal dummy 1
# 75                    MUN2                                  Municipal dummy 2
# 76                    MUN3                                  Municipal dummy 3
# 77                    MUN4                                  Municipal dummy 4
# 78                    MUN5                                  Municipal dummy 5
# 79                    MUN6                                  Municipal dummy 6
# 80              com_haz_05          community average baseline height-for-age
# 81              com_waz_05          community average baseline weight-for-age
# 82             com_tvip_05              Community average baseline tvip score
# 83          com_control_05         Community average baseline weight controls
# 84              com_vit_05       Community average children received vitamins
# 85           com_deworm_05  Community average children received deworming ...
# 86              com_notvip  Share of children in community without tvip sc...
# 94                sample06     =1 for children with at least one test in 2006
# 119           vitamiron_06               Got vitamin or iron in last 6 months
# 122              z_tvip_06                                  z-score tvip 2006
# 124            z_social_06          z-score denver social-personal score 2006
# 126          z_language_06                 z-score denver language score 2006
# 128          z_finmotor_06               z-score denver fine motor score 2006
# 130            z_memory_06              z-score memory for numbers score 2006
# 132           z_grmotor_06              z-score denver gross motor score 2006
# 134          z_legmotor_06                       z-score leg motor score 2006
# 136          z_behavior_06              z-score behavioral problem index 2006
# 138            z_height_06                        z-score height-for-age 2006
# 140            z_weight_06                        z-score weight-for-age 2006
# 143               z_all_06                   z-score of sum of all tests 2006
# 176            weighted_05                           Weighed in last 6 months
# 177            propfood_05                       % food in total expenditures
# 178            prstap_f_05               % staples in total food expenditures
# 179      pranimalprot_f_05       % animal proteins in total food expenditures
# 180        prfruitveg_f_05  % fruit and vegetables in total food expenditures
#
#      Type
# 2      ID
# 3      ID
# 12     ID
# 13   CONT
# 14    ORD
# 15    ORD
# 16    ORD
# 17    ORD
# 18    ORD
# 19    ORD
# 20    BIN
# 21    BIN
# 22    ORD
# 23   CONT
# 24   CONT
# 25   CONT
# 26    BIN
# 27    BIN
# 28    BIN
# 29    BIN
# 30    BIN
# 31    BIN
# 32   CONT
# 33   CONT
# 34   CONT
# 35   CONT
# 36   CONT
# 37   CONT
# 38    BIN
# 39    CAT
# 40   CONT
# 42   CONT
# 43   CONT
# 49    BIN
# 51   CONT
# 52   CONT
# 53   CONT
# 54    BIN
# 56    BIN
# 58    BIN
# 60    BIN
# 62   CONT
# 63   CONT
# 64   CONT
# 66     ID
# 67    BIN
# 68    BIN
# 69    BIN
# 70    BIN
# 71    BIN
# 72    BIN
# 73   CONT
# 74    BIN
# 75    BIN
# 76    BIN
# 77    BIN
# 78    BIN
# 79    BIN
# 80   CONT
# 81   CONT
# 82   CONT
# 83   CONT
# 84   FREQ
# 85   FREQ
# 86   CONT
# 94    BIN
# 119   BIN
# 122  CONT
# 124  CONT
# 126  CONT
# 128  CONT
# 130  CONT
# 132  CONT
# 134  CONT
# 136  CONT
# 138  CONT
# 140  CONT
# 143  CONT
# 176   BIN
# 177  FREQ
# 178  FREQ
# 179  FREQ
# 180  FREQ

# %%
df1=df[["hogarid_old","cp_old","unique_05","s1age_head_05","s1hhsize_05","s1hhsz_undr5_05","s1hhsz_5_14_05",
        "s1hhsz_15_24_05","s1hhsz_25_64_05","s1hhsz_65plus_05","s1male_head_05","s2mother_inhs_05","s3ap5_rooms_h_05",
        "s3ap23_stime_h_05","s3ap24_htime_h_05","s3ap25_hqtime_h_05","s3atoilet_hh_05","s3awater_access_hh_05",
        "s3aelectric_hh_05","s4p6_vitamina_i_05","s4p7_parasite_i_05","s11ownland_hh_05","cons_food_pc_05","cons_tot_pc_05",
        "tvip_05","height_05","a10whz_05","weight_05","itt_i","itt_all_i","yrsedfath","age_transfer","bweight",
        "s4p7_parasite_i_06","cpmom_06","T","male","TREAT1","TREAT2","TREAT3","TREAT4","ed_mom","MUN1","MUN2","MUN3","MUN4",
        "MUN5","MUN6","com_haz_05","com_waz_05","com_tvip_05","com_control_05","com_vit_05","com_deworm_05","com_notvip",
        "sample06","vitamiron_06","weighted_05","propfood_05","prstap_f_05","pranimalprot_f_05","prfruitveg_f_05"]]

# %%
df1.rename(columns = {'T':'tr'}, inplace = True)
# Out:
# C:\Users\Usuari\AppData\Local\Temp\ipykernel_11924\2300806653.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.rename(columns = {'T':'tr'}, inplace = True)

# %% [markdown]
# Las variables de resultado (*outcome*) engloban valores de tests cognitivos, psicomotores y de desarrollo físico. El objetivo del proyecto es predecir el valor de un subconjunto de dichos *outcomes*:

# %%
Feat_df.loc[(Feat_df.Prior_Knowledge == "O"), ['Variable_Name', 'Variable_Label', 'Type']]
# Out:
#         Variable_Name                              Variable_Label  Type
# 51      a5sscore_i_06                     TVIP standardized score  CONT
# 52    a6smemory_p1_06  standardize score McCarthy memory 1st part  CONT
# 53    a6smemory_p2_06  standardize score McCarthy memory 2nd part  CONT
# 54       a7a_delay_06     personal-social skills: delayed for age   BIN
# 56       a7b_delay_06            language skills: delayed for age   BIN
# 58       a7c_delay_06          fine motor skills: delayed for age   BIN
# 60       a7d_delay_06         gross motor skills: delayed for age   BIN
# 62   a9sgrossmotor_06      standardize score McCarthy gross motor  CONT
# 63          height_06         height for age z-score (antrop age)  CONT
# 64          weight_06          weight for age z-score(antrop age)  CONT
# 122         z_tvip_06                           z-score tvip 2006  CONT
# 124       z_social_06   z-score denver social-personal score 2006  CONT
# 126     z_language_06          z-score denver language score 2006  CONT
# 128     z_finmotor_06        z-score denver fine motor score 2006  CONT
# 130       z_memory_06       z-score memory for numbers score 2006  CONT
# 132      z_grmotor_06       z-score denver gross motor score 2006  CONT
# 134     z_legmotor_06                z-score leg motor score 2006  CONT
# 136     z_behavior_06       z-score behavioral problem index 2006  CONT
# 138       z_height_06                 z-score height-for-age 2006  CONT
# 140       z_weight_06                 z-score weight-for-age 2006  CONT
# 143          z_all_06            z-score of sum of all tests 2006  CONT

# %%
#df_out: dataframe de outcomes
df_out=df[["a5sscore_i_06","a6smemory_p1_06","a6smemory_p2_06","a7a_delay_06","a7b_delay_06",
        "a7c_delay_06","a7d_delay_06","a9sgrossmotor_06","height_06","weight_06","z_tvip_06","z_social_06",
        "z_language_06","z_finmotor_06","z_memory_06","z_grmotor_06","z_legmotor_06","z_behavior_06","z_height_06",
        "z_weight_06","z_all_06"]]

# %% [markdown]
# ## Exploración Inicial

# %% [markdown]
# ### Variables *outcome*

# %%
df_out
# Out:
#       a5sscore_i_06  a6smemory_p1_06  a6smemory_p2_06  a7a_delay_06  \
# 0               NaN              NaN              NaN           NaN
# 1              82.0        -0.294118        -0.166667           0.0
# 2              61.0        -1.444444        -0.937500           1.0
# 3              55.0        -3.111111        -0.937500           1.0
# 4               NaN              NaN              NaN           1.0
# ...             ...              ...              ...           ...
# 4506            NaN              NaN              NaN           NaN
# 4507            NaN              NaN              NaN           NaN
# 4508            NaN              NaN              NaN           NaN
# 4509            NaN              NaN              NaN           NaN
# 4510            NaN              NaN              NaN           NaN
#
#       a7b_delay_06  a7c_delay_06  a7d_delay_06  a9sgrossmotor_06  height_06  \
# 0              NaN           NaN           NaN               NaN        NaN
# 1              0.0           0.0           0.0          1.041667  -1.466107
# 2              1.0           0.0           0.0         -0.250000  -0.832335
# 3              1.0           1.0           1.0          0.750000  -1.540756
# 4              1.0           1.0           0.0               NaN  -2.187729
# ...            ...           ...           ...               ...        ...
# 4506           NaN           NaN           NaN               NaN        NaN
# 4507           NaN           NaN           NaN               NaN        NaN
# 4508           NaN           NaN           NaN               NaN        NaN
# 4509           NaN           NaN           NaN               NaN        NaN
# 4510           NaN           NaN           NaN               NaN        NaN
#
#       weight_06  ...  z_social_06  z_language_06  z_finmotor_06  z_memory_06  \
# 0           NaN  ...          NaN            NaN            NaN          NaN
# 1     -1.023752  ...     0.718433       0.710992       0.589500     0.428064
# 2     -0.381058  ...    -0.248101       0.261394       0.589500    -0.012619
# 3     -1.194815  ...    -0.248101      -1.087400      -2.478559    -1.334668
# 4     -2.005400  ...    -0.248101       0.261394      -1.711544          NaN
# ...         ...  ...          ...            ...            ...          ...
# 4506        NaN  ...          NaN            NaN            NaN          NaN
# 4507        NaN  ...          NaN            NaN            NaN          NaN
# 4508        NaN  ...          NaN            NaN            NaN          NaN
# 4509        NaN  ...          NaN            NaN            NaN          NaN
# 4510        NaN  ...          NaN            NaN            NaN          NaN
#
#       z_grmotor_06  z_legmotor_06  z_behavior_06  z_height_06  z_weight_06  \
# 0              NaN            NaN            NaN          NaN          NaN
# 1         0.519089       0.884574       0.710875    -0.188809    -0.057639
# 2         0.519089       0.553404      -2.688757     0.332960     0.460383
# 3        -0.628596       1.215745      -0.073655    -0.250266    -0.195518
# 4         0.519089            NaN            NaN    -0.782903    -0.848862
# ...            ...            ...            ...          ...          ...
# 4506           NaN            NaN            NaN          NaN          NaN
# 4507           NaN            NaN            NaN          NaN          NaN
# 4508           NaN            NaN            NaN          NaN          NaN
# 4509           NaN            NaN            NaN          NaN          NaN
# 4510           NaN            NaN            NaN          NaN          NaN
#
#       z_all_06
# 0          NaN
# 1     0.450156
# 2     0.011252
# 3    -0.505333
# 4    -0.468488
# ...        ...
# 4506       NaN
# 4507       NaN
# 4508       NaN
# 4509       NaN
# 4510       NaN
#
# [4511 rows x 21 columns]

# %% [markdown]
# Se investiga el número de datos faltantes (NaN) por variable para evaluar su gestión (omisión o imputación).

# %%
print(len(df_out[df_out.isnull().all(axis=1)].index),"individuos tienen NaN en todas las variables")
# Out:
# 1181 individuos tienen NaN en todas las variables

# %%
df_out.isnull().sum().sort_values() #Número de NaN por variable
# Out:
# z_all_06            1185
# a7a_delay_06        1200
# z_social_06         1204
# a7b_delay_06        1220
# z_language_06       1224
# a7c_delay_06        1242
# z_finmotor_06       1246
# a7d_delay_06        1254
# z_grmotor_06        1258
# z_height_06         1429
# height_06           1429
# weight_06           1429
# z_weight_06         1429
# a9sgrossmotor_06    2656
# a6smemory_p1_06     2669
# z_legmotor_06       2673
# a5sscore_i_06       2679
# z_memory_06         2684
# z_tvip_06           2694
# z_behavior_06       2891
# a6smemory_p2_06     3141
# dtype: int64

# %%
plt.hist(df_out.isnull().sum(axis=1), bins=21,facecolor='skyblue')
plt.ylabel('Nº Individuos')
plt.xlabel('NaN por individuo');

# %% [markdown]
# Según el histograma, vemos que a la mayoría les faltan 8 o 21 o 1 *outcomes*. Se estudia de qué *outcomes* se trata (celdas a continuación).
# - De los que les faltan 21, no se dispone de datos para ningún *outcome*.
# - A los que les faltan 8, les faltan datos para las variables "*a5sscore_y_06","*a6smemory_*p1_06", "*a9sgrossmotor_06", "z_*tvip_06", "z_*memory_06", "z_*legmotor_06", "z_*behavior_06". Es decir, no se les ha podido realizar los tests de memoria y psicomotricidad de McCarthy, el TVIP ni el test de Desarrollo Sociopersonal de Denver.
# - A los que les falta una sola variable, les falta o bien la 2ª parte del test de memoria de McCarthy, o bien el test de Denver.

# %%
NaN_df = pd.DataFrame()

for i in [1, 8, 21]:

    new_column = "#NaN = {}".format(i) 
    NaNdata = df_out[df_out.isnull().sum(axis=1)==i].isnull().sum()
    NaN_df = NaN_df.assign(**{new_column: NaNdata})

NaN_df
# Out:
#                   #NaN = 1  #NaN = 8  #NaN = 21
# a5sscore_i_06            0      1343       1181
# a6smemory_p1_06          0      1346       1181
# a6smemory_p2_06        323      1347       1181
# a7a_delay_06             0         0       1181
# a7b_delay_06             0         0       1181
# a7c_delay_06             0         0       1181
# a7d_delay_06             0         3       1181
# a9sgrossmotor_06         0      1346       1181
# height_06                0         1       1181
# weight_06                0         2       1181
# z_tvip_06                0      1343       1181
# z_social_06              0         0       1181
# z_language_06            0         0       1181
# z_finmotor_06            0         0       1181
# z_memory_06              0      1346       1181
# z_grmotor_06             0         3       1181
# z_legmotor_06            0      1346       1181
# z_behavior_06          147      1347       1181
# z_height_06              0         1       1181
# z_weight_06              0         2       1181
# z_all_06                 0         0       1181

# %% [markdown]
# La falta de valores para estos *outcomes* está estrechamente relacionada con la edad del sujeto (histogramas de edad según #NaN = [0, 1, 8, 21])

# %%
    fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

    NaN_counts = [21,0,8,1]
    
    for i in range(2):
        for j in range(2):

            ax = axes[i][j]

            n=NaN_counts[2*(j-1)+(i-1)]
            
            ax.hist(df1[df_out.isnull().sum(axis=1)==n].age_transfer, bins=70, color='skyblue', alpha=0.9, label='Nº NaN = {}'.format(n))
            ax.set_xlabel('Edad')
            ax.set_ylabel('Nº Individuos')
            ax.set_xlim([-40, 70])
            
            leg = ax.legend(loc='upper right')
            leg.draw_frame(False)
            
    fig.tight_layout()  
    plt.show()

# %% [markdown]
# Teniendo en cuenta que age_transfer <0 significa que el individuo nació posteriormente al inicio el tratamiento, a esos individuos no se les pudo realizar ciertos tests por no alcanzar sus límites de edad. Por este motivo, se decide omitir los datos para los que nacieron más de diez meses posteriormente al inicio del tratamiento (age_transfer < -10).

# %% [markdown]
# Deixant de banda els NaNs, explorem la relació entre la variable treatment i els diferents outcomes.

# %%
df_violin=pd.concat([df1, df_out])
df_violin["ct"]=0

# %%
col=df_out.columns
plt.figure(figsize=(10,30))
for i in range(21):
    plt.subplot(11,2,i+1)
    sns.violinplot(x="ct", y=col[i], hue="tr", data=df_violin, split=True, width=0.5)

# %% [markdown]
# # Income variables

# %%
df1=df[["hogarid_old","cp_old","unique_05","s1age_head_05","s1hhsize_05","s1hhsz_undr5_05","s1hhsz_5_14_05",
        "s1hhsz_15_24_05","s1hhsz_25_64_05","s1hhsz_65plus_05","s1male_head_05","s2mother_inhs_05","s3ap5_rooms_h_05",
        "s3ap23_stime_h_05","s3ap24_htime_h_05","s3ap25_hqtime_h_05","s3atoilet_hh_05","s3awater_access_hh_05",
        "s3aelectric_hh_05","s4p6_vitamina_i_05","s4p7_parasite_i_05","s11ownland_hh_05","cons_food_pc_05","cons_tot_pc_05",
        "tvip_05","height_05","a10whz_05","weight_05","itt_i","itt_all_i","yrsedfath","age_transfer","bweight",
        "s4p7_parasite_i_06","cpmom_06","T","male","TREAT1","TREAT2","TREAT3","TREAT4","ed_mom","MUN1","MUN2","MUN3","MUN4",
        "MUN5","MUN6","com_haz_05","com_waz_05","com_tvip_05","com_control_05","com_vit_05","com_deworm_05","com_notvip",
        "sample06","vitamiron_06","weighted_05","propfood_05","prstap_f_05","pranimalprot_f_05","prfruitveg_f_05"]]

# %%
df05=df1[["bweight","s4p7_parasite_i_06","cpmom_06","T","male","TREAT1","TREAT2","TREAT3","TREAT4","ed_mom","MUN1","MUN2","MUN3","MUN4",
        "MUN5","MUN6","com_haz_05","com_waz_05","com_tvip_05","com_control_05","com_vit_05","com_deworm_05","com_notvip",
        "sample06","vitamiron_06","weighted_05","propfood_05","prstap_f_05","pranimalprot_f_05","prfruitveg_f_05"]]

# %%
corr=df05.corr()
corr=abs(corr)
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_021c7_row0_col0, #T_021c7_row1_col1, #T_021c7_row2_col2, #T_021c7_row2_col4, #T_021c7_row3_col3, #T_021c7_row4_col2, #T_021c7_row4_col4, #T_021c7_row5_col5, #T_021c7_row6_col6, #T_021c7_row7_col7, #T_021c7_row8_col8, #T_021c7_row9_col9, #T_021c7_row10_col10, #T_021c7_row11_col11, #T_021c7_row12_col12, #T_021c7_row13_col13, #T_021c7_row14_col14, #T_021c7_row15_col15, #T_021c7_row16_col16, #T_021c7_row17_col17, #T_021c7_row18_col18, #T_021c7_row19_col19, #T_021c7_row20_col20, #T_021c7_row21_col21, #T_021c7_row22_col22, #T_021c7_row23_col23, #T_021c7_row24_col24, #T_021c7_row25_col25, #T_021c7_row26_col26, #T_021c7_row27_col27, #T_021c7_row28_col28 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_021c7_row0_col1, #T_021c7_row0_col5, #T_021c7_row0_col26, #T_021c7_row1_col0, #T_021c7_row3_col16, #T_021c7_row5_col0, #T_021c7_row5_col10, #T_021c7_row5_col16, #T_021c7_row5_col27, #T_021c7_row6_col23, #T_021c7_row6_col27, #T_021c7_row7_col11, #T_021c7_row8_col10, #T_021c7_row10_col8, #T_021c7_row10_col23, #T_021c7_row10_col24, #T_021c7_row11_col7, #T_021c7_row11_col18, #T_021c7_row13_col5, #T_021c7_row14_col19, #T_021c7_row15_col10, #T_021c7_row16_col5, #T_021c7_row16_col23, #T_021c7_row18_col0, #T_021c7_row18_col9, #T_021c7_row19_col1, #T_021c7_row20_col0, #T_021c7_row21_col0, #T_021c7_row22_col23, #T_021c7_row23_col6, #T_021c7_row23_col10, #T_021c7_row23_col16, #T_021c7_row23_col22, #T_021c7_row26_col0, #T_021c7_row27_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_021c7_row0_col2, #T_021c7_row0_col4, #T_021c7_row0_col7, #T_021c7_row0_col22, #T_021c7_row0_col23, #T_021c7_row1_col7, #T_021c7_row1_col21, #T_021c7_row2_col0, #T_021c7_row2_col26, #T_021c7_row3_col7, #T_021c7_row3_col10, #T_021c7_row3_col11, #T_021c7_row3_col12, #T_021c7_row3_col13, #T_021c7_row3_col15, #T_021c7_row3_col18, #T_021c7_row3_col20, #T_021c7_row3_col24, #T_021c7_row3_col26, #T_021c7_row3_col28, #T_021c7_row4_col0, #T_021c7_row4_col26, #T_021c7_row5_col25, #T_021c7_row6_col9, #T_021c7_row6_col14, #T_021c7_row6_col26, #T_021c7_row6_col28, #T_021c7_row7_col0, #T_021c7_row7_col1, #T_021c7_row7_col13, #T_021c7_row8_col13, #T_021c7_row8_col23, #T_021c7_row9_col6, #T_021c7_row9_col23, #T_021c7_row10_col3, #T_021c
{
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_23b9c_row0_col4, #T_23b9c_row0_col24, #T_23b9c_row0_col47, #T_23b9c_row1_col21, #T_23b9c_row3_col43, #T_23b9c_row4_col33, #T_23b9c_row6_col17, #T_23b9c_row6_col29, #T_23b9c_row7_col6, #T_23b9c_row7_col51, #T_23b9c_row8_col2, #T_23b9c_row8_col23, #T_23b9c_row8_col40, #T_23b9c_row8_col43, #T_23b9c_row9_col10, #T_23b9c_row9_col21, #T_23b9c_row9_col38, #T_23b9c_row9_col49, #T_23b9c_row10_col21, #T_23b9c_row10_col32, #T_23b9c_row10_col38, #T_23b9c_row10_col39, #T_23b9c_row11_col15, #T_23b9c_row12_col20, #T_23b9c_row12_col42, #T_23b9c_row13_col8, #T_23b9c_row13_col10, #T_23b9c_row14_col25, #T_23b9c_ro

# %%
k=1
#print( "(",col[i+k],")", col.index[i+k]," - ", column,"\n")
high_corr=[]
for column in corr.columns:
    col=corr[column]
    for i in range(len(col)-k):
        if(col[i+k]>0.5):
            high_corr.append([col[i+k], col.index[i+k], column]) 
    k=k+1
high_corr_series=pd.Series([row[0] for row in high_corr], index=[row[1]+" - "+row[2] for row in high_corr])

# %%
high_corr_series.sort_values()
# Out:
# com_waz_05 - MUN1                         0.501341
# s1hhsz_15_24_05 - cp_old                  0.502381
# s1hhsize_05 - s1age_head_05               0.513081
# com_waz_05 - unique_05                    0.520361
# s1age_head_05 - cp_old                    0.521741
# s1hhsz_15_24_05 - s1hhsize_05             0.531419
# s1hhsz_65plus_05 - s1age_head_05          0.548293
# com_haz_05 - unique_05                    0.551994
# cpmom_06 - s1hhsz_15_24_05                0.552210
# cpmom_06 - cp_old                         0.587112
# cpmom_06 - s1hhsize_05                    0.587361
# s1hhsz_25_64_05 - cp_old                  0.590757
# s3ap25_hqtime_h_05 - s3ap24_htime_h_05    0.630219
# com_haz_05 - MUN1                         0.631204
# s1hhsz_25_64_05 - s1hhsize_05             0.646196
# sample06 - age_transfer                   0.655035
# pranimalprot_f_05 - prstap_f_05           0.664587
# weight_05 - a10whz_05                     0.696645
# s1hhsz_5_14_05 - s1hhsize_05              0.703613
# s1hhsz_5_14_05 - cp_old                   0.707163
# MUN3 - unique_05                          0.729333
# com_deworm_05 - com_vit_05                0.749239
# weight_05 - height_05                     0.759777
# com_waz_05 - com_haz_05                   0.860696
# s1hhsize_05 - cp_old                      0.917750
# cons_tot_pc_05 - cons_food_pc_05          0.947735
# TREAT1 - T                                1.000000
# dtype: float64

# %% [markdown]
# Variables altament relacionades:
#
#    - TREAT1 - T: Treatment1 i treatment, efectivament qui és tractat, com a mínim és tractat amb T1, i qui és tractat amb T1 és tractat.
#
#    - cons_tot_pc_05 - cons_food_pc_05: gasto total i gasto en menjar.
#
#    - s1hhsize_05 - cp_old: mida hh i codi personal
#
#    - com_waz_05 - com_haz_05: community average baseline height-for-age vs community average baseline weight-for-age
#
#    - weight_05 - height_05: pes i alçada.

# %% [markdown]
# Provem per altres mesures de correlació: spearman i kendall.

# %%
corr_kendall=df1.corr(method='kendall')
corr_kendall=abs(corr_kendall)
corr_kendall.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_720fd_row0_col0, #T_720fd_row1_col1, #T_720fd_row2_col2, #T_720fd_row3_col3, #T_720fd_row4_col4, #T_720fd_row5_col5, #T_720fd_row6_col6, #T_720fd_row7_col7, #T_720fd_row8_col8, #T_720fd_row9_col9, #T_720fd_row10_col10, #T_720fd_row11_col11, #T_720fd_row12_col12, #T_720fd_row13_col13, #T_720fd_row14_col14, #T_720fd_row15_col15, #T_720fd_row16_col16, #T_720fd_row17_col17, #T_720fd_row18_col18, #T_720fd_row19_col19, #T_720fd_row20_col20, #T_720fd_row21_col21, #T_720fd_row22_col22, #T_720fd_row23_col23, #T_720fd_row24_col24, #T_720fd_row25_col25, #T_720fd_row25_col27, #T_720fd_row26_col26, #T_720fd_row27_col25, #T_720fd_row27_col27, #T_720fd_row28_col28, #T_720fd_row29_col29, #T_720fd_row30_col30, #T_720fd_row31_col31, #T_720fd_row32_col32, #T_720fd_row33_col33, #T_720fd_row34_col34, #T_720fd_row35_col35, #T_720fd_row36_col36, #T_720fd_row37_col37, #T_720fd_row38_col38, #T_720fd_row39_col39, #T_720fd_row40_col40, #T_720fd_row41_col41, #T_720fd_row42_col42, #T_720fd_row43_col43, #T_720fd_row44_col44, #T_720fd_row45_col45, #T_720fd_row46_col46, #T_720fd_row47_col47, #T_720fd_row48_col48, #T_720fd_row49_col49, #T_720fd_row50_col50, #T_720fd_row51_col51 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_720fd_row0_col1, #T_720fd_row0_col6, #T_720fd_row0_col26, #T_720fd_row1_col0, #T_720fd_row1_col26, #T_720fd_row1_col47, #T_720fd_row2_col17, #T_720fd_row3_col31, #T_720fd_row3_col42, #T_720fd_row3_col47, #T_720fd_row3_col50, #T_720fd_row4_col14, #T_720fd_row4_col28, #T_720fd_row5_col29, #T_720fd_row6_col9, #T_720fd_row6_col12, #T_720fd_row6_col46, #T_720fd_row7_col18, #T_720fd_row7_col42, #T_720fd_row8_col30, #T_720fd_row8_col37, #T_720fd_row8_col41, #T_720fd_row9_col6, #T_720fd_row10_col12, #T_720fd_row10_col16, #T_720fd_row10_col18, #T_720fd_row10_col30, #T_720fd_row10_col40, #T_720fd_row10_col42, #T_720fd_row10_col48, #T_720fd_row10_col49, #T_720fd_row11_col36, #T_720fd_row11_col46, #T_720fd_row12_col3, #T_720fd_row12_col6, #T_720fd_row12_col10, #T_720fd_row12_col24, #T_720fd_row12_col26, #T_720fd_row12_col28, #T_720fd_row12_col45, #T_720fd_row12_col47, #T_720fd_row13_col8, #T_720fd_row13_col46, #T_720fd_row15_col41, #T_720fd_row16_col30, #T_720fd_row16_col41, #T_720fd_row16_col46, #T_720fd_row17_col36, #T_720fd_row17_col42, #T_720fd_row18_col7, #T_720fd_row19_col26, #T_720fd_row19_col33, #T_720fd_row19_col40, #T_720fd_row19_col46, #T_720fd_row19_col47, #T_720fd_row20_col8, #T_720fd_row20_col40, #T_720fd_row21_col8, #T_720fd_row21_col43, #T_720fd_row22_col30, #T_720fd_row22_col32, #T_720fd_row24_col12, #T_720fd_row25_col11, #T_720fd_row26_col0, #T_720fd_row26_col12, #T_720fd_row26_col19, #T_720fd_row27_col11, #T_720fd_row28_col3, #T_720fd_row28_col4, #T_720fd_row28_col12, #T_720fd_row28_col50, #T_720fd_row29_col5, #T_720fd_row29_col48, #T_720fd_row29_col50, #T_720fd_row30_col10, #T_720fd_row30_col12, #T_720fd_row30_col16, #T_720fd_row30_col22, #T_720fd_row30_col37, #T_720fd_row30_col45, #T_720fd_row31_col3, #T_720fd_row32_col22, #T_720fd_row32_col42, #T_720fd_row33_col19, #T_720fd_row36_col11, #T_720fd_row36_col17, #T_720fd_row37_col8, #T_720fd_row37_col42, #T_720fd_row38_col19, #T_720fd_row38_col33, #T_720fd_row38_col41, #T_720fd_row38_col46, #T_720fd_row40_col10, #T_720fd_row40_col42, #T_720fd_row41_col15, #T_720fd_row41_col16, #T_720fd_row42_col7, #T_720fd_row42_col8, #T_720fd_row42_col31, #T_720fd_row42_col32, #T_720fd_row42_col37, #T_720fd_row42_col40, #T_720fd_row42_col44, #T_720fd_row42_col45, #T_720fd_row43_col7, #T_720fd_row43_col10, #T_720fd_row43_col12, #T_720fd_row43_col20, #T_720fd_row43_col32, #T_720fd_row44_col1, #T_720fd_row45_col12, #T_720fd_row45_col13, #T_720fd_row45_col25, #T_720fd_row45_col27, #T_720fd_row45_col30, #T_720fd_row45_col37, #T_720fd_row45_col42, #T_720fd_row46_col3, #T_720fd_row46_col6, #T_720fd_row46_col11, #T_720fd_row46_col13, #T_720fd_row46_col16, #T_720fd_row46_col19, #T_720fd_row46_col43, #T_720fd_row46_col51, #T_720fd_row47_col3, #T_720fd_row47_col12, #T_720fd_row47_col19, #T_720fd_row48_col10, #T_720fd_row49_col10, #T_720fd_row49_col24, #T_720fd_row50_col24, #T_720fd_row50_col41, #T_720fd_row50_col45, #T_720fd_row51_col8, #T_720fd_row51_col46 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_720fd_row0_col2, #T_720fd_row4_col18, #T_720fd_row5_col49, #T_720fd_row11_col48, #T_720fd_row12_col13, #T_720fd_row13_col40, #T_720fd_row13_col48, #T_720fd_row18_col4, #T_720fd_row18_col11, #T_720fd_row19_col22, #T_720fd_row19_col23, #T_720fd_row19_col39, #T_720fd_row21_col24, #T_720fd_row22_col19, #T_720fd_row23_col19, #T_720fd_row24_col21, #T_720fd_row33_col35, #T_720fd_row33_col37, #T_720fd_row35_col33, #T_720fd_row37_col33, #T_720fd_row39_col19, #T_720fd_row40_col13, #T_720fd_row49_col1, #T_720fd_row49_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_720fd_row0_col3, #T_720fd_row0_col5, #T_720fd_row0_col10, #T_720fd_row0_col17, #T_720fd_row0_col19, #T_720fd_row0_col45, #T_720fd_row1_col13, #T_720fd_row1_col34, #T_720fd_row1_col42, #T_720fd_row1_col43, #T_720fd_row1_col45, #T_720fd_row2_col46, #T_720fd_row3_col0, #T_720fd_row3_col12, #T_720fd_row3_col28, #T_720fd_row3_col34, #T_720fd_row3_col36, #T_720fd_row3_col46, #T_720fd_row3_col49, #T_720fd_row4_col13, #T_720fd_row4_col21, #T_720fd_row5_col7, #T_720fd_row5_col9, #T_720fd_row5_col10, #T_720fd_row5_col33, #T_720fd_row6_col0, #T_720fd_row6_col26, #T_720fd_row6_col44, #T_720fd_row7_col5, #T_720fd_row7_col19, #T_720fd_row7_col33, #T_720fd_row7_col40, #T_720fd_row7_col43, #T_720fd_row8_col25, #T_720fd_row8_col26, #T_720fd_row8_col27, #T_720fd_row8_col28, #T_720fd_row8_col29, #T_720fd_row8_col31, #T_720fd_row8_col40, #T_720fd_row8_col50, #T_720fd_row9_col5, #T_720fd_row9_col26, #T_720fd_row10_col5, #T_720fd_row10_col15, #T_720fd_row10_col43, #T_720fd_row10_col44, #T_720fd_row12_col22, #T_720fd_row12_col30, #T_720fd_row12_col33, #T_720fd_row12_col42, #T_720fd_row12_col43, #T_720fd_row13_col4, #T_720fd_row13_col19, #T_720fd_row13_col28, #T_720fd_row13_col30, #T_720fd_row14_col4, #T_720fd_row14_col28, #T_720fd_row15_col10, #T_720fd_row16_col25, #T_720fd_row16_col27, #T_720fd_row17_col0, #T_720fd_row17_col3, #T_720fd_row17_col6, #T_720fd_row17_col29, #T_720fd_row19_col0, #T_720fd_row19_col7, #T_720fd_row19_col13, #T_720fd_row19_col25, #T_720fd_row19_col27, #T_720fd_row19_col34, #T_720fd_row19_col35, #T_720fd_row19_col38, #T_720fd_row20_col43, #T_720fd_row20_col46, #T_720fd_row21_col30, #T_720fd_row22_col12, #T_720fd_row22_col25, #T_720fd_row22_col27, #T_720fd_row22_col33, #T_720fd_row22_col44, #T_720fd_row22_col49, #T_720fd_row24_col44, #T_720fd_row24_col50, #T_720fd_row25_col16, #T_720fd_row25_col19, #T_720fd_row25_col22, #T_720fd_row25_col31, #T_720fd_row25_col36, #T_720fd_row25_col45, #T_720fd_row26_col6, #T_720fd_row26_col9, #T_720fd_row26_col46, #T_720fd_row27_col16, #T_720fd_row27_col19, #T_720fd_row27_col22, #T_720fd_row27_col31, #T_720fd_row27_col36, #T_720fd_row27_col45, #T_720fd_row28_col8, #T_720fd_row28_col13, #T_720fd_row28_col14, #T_720fd_row28_col34, #T_720fd_row28_col35, #T_720fd_row28_col49, #T_720fd_row30_col8, #T_720fd_row30_col13, #T_720fd_row30_col21, #T_720fd_row30_col47, #T_720fd_row31_col8, #T_720fd_row31_col10, #T_720fd_row31_col25, #T_720fd_row31_col27, #T_720fd_row32_col26, #T_720fd_row32_col43, #T_720fd_row33_col5, #T_720fd_row33_col7, #T_720fd_row33_col12, #T_720fd_row33_col22, #T_720fd_row33_col45, #T_720fd_row34_col3, #T_720fd_row34_col19, #T_720fd_row34_col28, #T_720fd_row35_col19, #T_720fd_row35_col47, #T_720fd_row36_col3, #T_720fd_row36_col25, #T_720fd_row36_col27, #T_720fd_row36_col45, #T_720fd_row37_col30, #T_720fd_row37_col45, #T_720fd_row38_col47, #T_720fd_row39_col45, #T_720fd_row40_col7, #T_720fd_row40_col8, #T_720fd_row40_col43, #T_720fd_row41_col8, #T_720fd_row41_col50, #T_720fd_row42_col3, #T_720fd_row42_col10, #T_720fd_row42_col12, #T_720fd_row42_col17, #T_720fd_row42_col46, #T_720fd_row43_col1, #T_720fd_row43_col40, #T_720fd_row43_col51, #T_720fd_row44_col6, #T_720fd_row44_col10, #T_720fd_ro

# %%
k=1
#print( "(",col[i+k],")", col.index[i+k]," - ", column,"\n")
high_corr_k=[]
for column in corr_kendall.columns:
    col=corr_kendall[column]
    for i in range(len(col)-k):
        if(col[i+k]>0.5):
            high_corr_k.append([col[i+k], col.index[i+k], column]) 
    k=k+1
high_corr_k_series=pd.Series([row[0] for row in high_corr_k], index=[row[1]+" - "+row[2] for row in high_corr_k])
high_corr_k_series.sort_values()
# Out:
# sample06 - age_transfer                   0.523202
# s1hhsz_25_64_05 - s1hhsize_05             0.523610
# com_haz_05 - MUN1                         0.526786
# weight_05 - a10whz_05                     0.529515
# s3ap25_hqtime_h_05 - s3ap24_htime_h_05    0.539837
# com_deworm_05 - com_vit_05                0.567326
# weight_05 - height_05                     0.569494
# s1hhsz_5_14_05 - s1hhsize_05              0.588778
# MUN4 - unique_05                          0.594208
# s1hhsz_5_14_05 - cp_old                   0.605742
# com_waz_05 - com_haz_05                   0.690263
# cons_tot_pc_05 - cons_food_pc_05          0.742154
# s1hhsize_05 - cp_old                      0.850874
# TREAT1 - T                                1.000000
# dtype: float64

# %%
corr_sp=df1.corr(method='spearman')
corr_sp=abs(corr_sp)
corr_sp.style.background_gradient(cmap='coolwarm')

k=1
#print( "(",col[i+k],")", col.index[i+k]," - ", column,"\n")
high_corr_sp=[]
for column in corr_sp.columns:
    col=corr_sp[column]
    for i in range(len(col)-k):
        if(col[i+k]>0.5):
            high_corr_sp.append([col[i+k], col.index[i+k], column]) 
    k=k+1
high_corr_sp_series=pd.Series([row[0] for row in high_corr_sp], index=[row[1]+" - "+row[2] for row in high_corr_sp])
high_corr_sp_series.sort_values()
# Out:
# com_waz_05 - unique_05                    0.524321
# s1hhsz_25_64_05 - s1age_head_05           0.535615
# MUN3 - unique_05                          0.574174
# cpmom_06 - s1age_head_05                  0.591148
# s1hhsz_25_64_05 - cp_old                  0.592082
# com_haz_05 - unique_05                    0.594705
# s1hhsize_05 - s1age_head_05               0.611948
# s1hhsz_25_64_05 - s1hhsize_05             0.621115
# s1age_head_05 - cp_old                    0.628457
# s3ap25_hqtime_h_05 - s3ap24_htime_h_05    0.628912
# sample06 - age_transfer                   0.637752
# com_haz_05 - MUN1                         0.640484
# pranimalprot_f_05 - prstap_f_05           0.651872
# s1hhsz_5_14_05 - s1hhsize_05              0.701547
# s1hhsz_5_14_05 - cp_old                   0.711241
# weight_05 - a10whz_05                     0.713498
# MUN4 - unique_05                          0.722458
# com_deworm_05 - com_vit_05                0.742241
# weight_05 - height_05                     0.758025
# com_waz_05 - com_haz_05                   0.853945
# cons_tot_pc_05 - cons_food_pc_05          0.897715
# s1hhsize_05 - cp_old                      0.924589
# TREAT1 - T                                1.000000
# dtype: float64
