# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data import

# %%
df = pd.read_stata('Cash_and_Childhood_Development_Replication\macoursetal_main.dta')

# %%
df
# Out:
#          hogarid08    cp  hogarid_old  cp_old  age_months_08   hogarid06  i06  \
# 0     7.005310e+11   5.0     70053101     NaN           33.0  70053101.0  1.0
# 1     7.005330e+11   5.0     70053301     5.0           77.0  70053301.0  1.0
# 2     7.005340e+11   8.0     70053401     8.0           93.0  70053401.0  1.0
# 3     7.005370e+11   7.0     70053701     7.0           97.0  70053701.0  1.0
# 4     7.005370e+11  10.0     70053701    10.0           43.0  70053701.0  1.0
# ...            ...   ...          ...     ...            ...         ...  ...
# 4506  7.034900e+11  13.0     70349001     NaN           22.0         NaN  NaN
# 4507  7.046830e+11   8.0     70468301     NaN            7.0         NaN  NaN
# 4508  7.008170e+11   4.0     70081701     NaN           20.0         NaN  NaN
# 4509  7.014790e+11   5.0     70147901     NaN           11.0         NaN  NaN
# 4510  7.030020e+11   8.0     70300201     NaN           22.0         NaN  NaN
#
# ...

# %% [markdown]
# We have selected only the CONT variables from the Split1 (input variables) for an exploratory data cleaning

# %%
df1=df[["s1age_head_05","s3ap23_stime_h_05","s3ap24_htime_h_05","s3ap25_hqtime_h_05","cons_food_pc_05","cons_tot_pc_05","tvip_05","height_05","a10whz_05","weight_05","yrsedfath","age_transfer","bweight","ed_mom","com_haz_05","com_waz_05","com_tvip_05","com_control_05","com_notvip"]]

df1
# Out:
#       s1age_head_05  s3ap23_stime_h_05  s3ap24_htime_h_05  s3ap25_hqtime_h_05  \
# 0              30.0           0.083333           0.500000            2.000000
# 1              35.0           0.050000           1.250000            2.500000
# 2              56.0           0.083333           0.500000            0.666667
# 3              49.0           0.033333           2.000000            2.000000
# 4              49.0           0.033333           2.000000            2.000000
# ...             ...                ...                ...                 ...
# 4506           47.0           0.083333           0.666667            0.666667
# 4507           51.0           0.250000           3.000000            3.000000
# 4508           32.0           0.500000           0.500000            2.500000
# 4509           25.0           1.000000           3.000000            6.000000
# 4510           57.0           0.583333           0.583333            0.583333
#
# ...

# %% [markdown]
# The 46 empty data entries are dropped:

# %%
df1.drop([323,375,466,513,539,639,728,782,783,846,858,914,1048,1504,1577,1611,2078,2147,2153,2384,2404,2473,2592,2613,2620,2736,2770,2912,2969,3079,3157,3182,3584,3674,3768,3811,3817,3821,3875,3932,3936,3943,4002,4211,4448,4470], axis=0, inplace=True)
df1.isna().sum().sort_values()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# s1age_head_05            0
# com_tvip_05              0
# com_waz_05               0
# com_haz_05               0
# age_transfer             0
# com_control_05           0
# com_notvip               0
# cons_tot_pc_05           0
# s3ap25_hqtime_h_05       0
# s3ap24_htime_h_05        0
# s3ap23_stime_h_05        0
# cons_food_pc_05        127
# ed_mom                 257
# yrsedfath              456
# bweight               1598
# weight_05             1998
# height_05             2007
# a10whz_05             2046
# tvip_05               3362
# dtype: int64

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
def histograms_plot(dataframe, features, rows, cols, binNum, xsize=20, ysize=20):

    fig=plt.figure(figsize=(xsize,ysize))
    for i, feature in enumerate(features):
        ax=fig.add_subplot(rows,cols,i+1)
        dataframe[feature].hist(bins=binNum,ax=ax,facecolor='skyblue')
        ax.set_title(feature,color='purple')

    fig.tight_layout()  
    plt.show()

# %%
histograms_plot(df1,df1.columns,7,3,20)

# %% [markdown]
# 1. bweight               (1598)
# 1. weight_05             (1998)
# 1. height_05            (2007)
# 1. a10whz_05             (2046)
#
# These variables are the more apparently normally distributed (all but bweight are Z-scores) but have many NaN: problably due to the child not having been born when the treatment started. We check the missing values to age_transfer.

# %%
df1["bweight_miss"]=df1.bweight.isna()

ax = sns.boxplot(x="bweight_miss",y="age_transfer", data=df1)

# %%
df1["weight_05_miss"]=df1.weight_05.isna()

ax = sns.boxplot(x="weight_05_miss",y="age_transfer", data=df1)

# %%
df1["height_05_miss"]=df1.height_05.isna()

ax = sns.boxplot(x="height_05_miss",y="age_transfer", data=df1)

# %%
df1["a10whz_05_miss"]=df1.a10whz_05.isna()

ax = sns.boxplot(x="a10whz_05_miss",y="age_transfer", data=df1)

# %% [markdown]
# # Normality test
#
# We perform a Shapiro-Wilk Normality Test to better assess normality on all the continuous variables.

# %%
from scipy.stats import shapiro

# %%
def shapiro_to_features(dataframe, features):

    for i, feature in enumerate(features):
        stat, p = shapiro(dataframe[feature].dropna())
        print (feature)
        print((stat,p))

# %%
shapiro_to_features(df1,df1.columns)
# Out:
# s1age_head_05
# (0.9444149136543274, 4.460191200541303e-38)
# s3ap23_stime_h_05
# (0.7512198090553284, 0.0)
# s3ap24_htime_h_05
# (0.8877214193344116, 0.0)
# s3ap25_hqtime_h_05
# (0.8805122375488281, 0.0)
# cons_food_pc_05
# (0.33069533109664917, 0.0)
# cons_tot_pc_05
# (0.482343852519989, 0.0)
# tvip_05
# (0.7153283357620239, 1.1560025694432222e-39)
# height_05
# (0.9924212098121643, 5.059175856025888e-10)
# a10whz_05
# (0.9908662438392639, 2.9766761971972144e-11)
# weight_05
# (0.9901964068412781, 6.15448924462525e-12)
# yrsedfath
# (0.8951202630996704, 0.0)
# age_transfer
# (0.956274151802063, 1.2191608665073402e-34)
# bweight
# (0.8831321001052856, 4.062364248077645e-42)
# ed_mom
# (0.9368410110473633, 4.8453579818991724e-39)
# com_haz_05
# (0.9816938042640686, 1.34936913980243e-23)
# com_waz_05
# (0.9906561970710754, 1.3626784152274426e-16)
# com_tvip_05
# (0.8638273477554321, 0.0)
# com_control_05
# (0.9022786021232605, 0.0)
# com_notvip
# ...

# %% [markdown]
# According to these results, none of the variables is normal, not even the apparently normal: bweight, weight_05, height_05, a10whz_05. Upon closer inspection of the histograms:

# %%
histograms_plot(df1,["bweight"],1,1,20, 5,3)

# %%
histograms_plot(df1,["bweight"],1,1,40, 5,3)

# %%
histograms_plot(df1,["bweight"],1,1,80, 5,3)

# %% [markdown]
# # Outliers
#
# Trying an Isolation Forest approach (for non-Z-score variables!)

# %%
from sklearn.ensemble import IsolationForest

random_state = np.random.RandomState(42)

model=IsolationForest(n_estimators=100,max_samples='auto',contamination=float(0.01),random_state=random_state)

model.fit(df1[['bweight']].dropna())
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:223: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\ensemble\bagging.py:313: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   elif isinstance(self.max_features, np.float):
# ...

# %%
df2 = pd.DataFrame()

df2["value"] = df1[['bweight']].dropna()

df2['scores'] = model.decision_function(df1[['bweight']].dropna())

df2['anomaly_score'] = model.predict(df1[['bweight']].dropna())

ax = sns.boxplot(x="anomaly_score",y="value", data=df2)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:417: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)

# %%
print(df2[df2["anomaly_score"]==1].count())
print(df2[df2["anomaly_score"]==-1].count())
# Out:
# value            2839
# scores           2839
# anomaly_score    2839
# dtype: int64
# value            28
# scores           28
# anomaly_score    28
# dtype: int64

# %% [markdown]
# MAYBE NORMALITY IS ACHIEVED BY DROPPING OUTLIERS

# %%
df3 = pd.DataFrame()

a= list(df2[df2["anomaly_score"]==-1].index)
a=np.reshape(a, -1)

df3["value"]= df1.drop(a)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'value'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# # NaN Management
#
# Robby Goetschalckx
#
# First, try to verify whether the data points are missing "completely at random", that means independent of the value. If, for a variable, specific values are more likely to not show than others, this needs to be taken into account. When it can depend on the values of other variables, it becomes even harder.
#
# For now, I'll assume they are missing completely at random.
#
# Any prediction algorithm for the variable (classification for discrete variables, regression for numerical values) can be used for imputation. Try using a number of different predictors to obtain robustness, for example use 5 different algorithms and use majority voting (for classification) or the mean (for regression).
#
# There are many algorithms out there, and some might be better suited for your data set than others.

# %% [markdown]
# # Scaling/Normalization/Standarization
#
# https://www.analyticsvidhya.com/blog/2020/04/feature-scaling-machine-learning-normalization-standardization/
#
# Normalization is a scaling technique in which values are shifted and rescaled so that they end up ranging between 0 and 1. It is also known as Min-Max scaling.
#
# Standardization is another scaling technique where the values are centered around the mean with a unit standard deviation. This means that the mean of the attribute becomes zero and the resultant distribution has a unit standard deviation.
#
# 1. Normalization is good to use when you know that the distribution of your data does not follow a Gaussian distribution. This can be useful in algorithms that do not assume any distribution of the data like K-Nearest Neighbors and Neural Networks.
# 1. Standardization, on the other hand, can be helpful in cases where the data follows a Gaussian distribution. However, this does not have to be necessarily true. Also, unlike normalization, standardization does not have a bounding range. So, even if you have outliers in your data, they will not be affected by standardization.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# data normalization with sklearn
from sklearn.preprocessing import MinMaxScaler

# fit scaler on training data
norm = MinMaxScaler().fit(X_train)

# transform training data
X_train_norm = norm.transform(X_train)

# transform testing dataabs
X_test_norm = norm.transform(X_test)

# %% [markdown]
# Because One-Hot encoded features are already in the range between 0 to 1, normalization would not affect their value.

# %%
# data standardization with  sklearn
from sklearn.preprocessing import StandardScaler

# copy of datasets
X_train_stand = X_train.copy()
X_test_stand = X_test.copy()

# numerical features
num_cols = ['Item_Weight','Item_Visibility','Item_MRP','Outlet_Establishment_Year']

# apply standardization on numerical features
for i in num_cols:
    
    # fit on training data column
    scale = StandardScaler().fit(X_train_stand[[i]])
    
    # transform the training data column
    X_train_stand[i] = scale.transform(X_train_stand[[i]])
    
    # transform the testing data column
    X_test_stand[i] = scale.transform(X_test_stand[[i]])
